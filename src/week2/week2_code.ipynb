# %% [markdown]
# # In Class Examples | Week 2 | AIST 2110 | UNIX Basic Commands

# %% [markdown]
# ## Review

# %%
! git commit -a -m "Week 2 added"
! git push

# %% [markdown]
# ## Printing Current Directory

# %%
! pwd

# %% [markdown]
# ## Listing files in Current Directory

# %%
! ls

# %%
! ls -a # lists all files including hidden files

# %%
! ls -l # lists files in long format

# %%
! ls -la # Combine both options

# %% [markdown]
# ## Changing Directories

# %%
! cd ..; pwd # Moving up one directory level
! cd ../week2; pwd
! cd ../week3; pwd

# %% [markdown]
# ## Concatenating Files

# %%
! cat test.txt

# %% [markdown]
# ## To Cover in class:
# - Accessing the following repos:
#     - In-Class-Examples
#     - Assign2
#     - Overall class org
# - VSC Tour
# - All cmds in the workspace's terminal (w/ ex)
# - Work thru question 1
#     - cd `../w[tab]/[workshop]`
#     - Perhaps `tree` usage?

# %% [markdown]
# Created by Seth Barrett | 2025
